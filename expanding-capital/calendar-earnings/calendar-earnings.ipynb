# %% [markdown]
# # 1. Installing

# %%
! pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib gspread
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.169.0)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.2.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.2.2)
# Requirement already satisfied: gspread in /usr/local/python/3.12.1/lib/python3.12/site-packages (6.2.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client) (2.39.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (6.30.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /home/codespace/.local/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/codespace/.local/lib/python3.12/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2025.1.31)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
! pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib gspread pandas openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.169.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting google-auth-httplib2
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth-oauthlib
#   Downloading google_auth_oauthlib-1.2.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 (from google-api-python-client)
#   Downloading google_auth-2.39.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client)
#   Downloading google_api_core-2.24.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading protobuf-6.30.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\rafat\appdata\roaming\python\python313\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.3)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\rafat\appdata\roaming\python\python313\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.3)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib)
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rafat\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rafat\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rafat\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rafat\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2025.4.26)
# Downloading google_api_python_client-2.169.0-py3-none-any.whl (13.3 MB)
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/13.3 MB 7.9 MB/s eta 0:00:02
#    --------- ------------------------------ 3.1/13.3 MB 8.4 MB/s eta 0:00:02
#    -------------- ------------------------- 4.7/13.3 MB 8.3 MB/s eta 0:00:02
#    ------------------ --------------------- 6.3/13.3 MB 7.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.6/13.3 MB 7.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.4/13.3 MB 7.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.7/13.3 MB 7.5 MB/s eta 0:00:01
#    -------------------------------- ------- 10.7/13.3 MB 7.5 MB/s eta 0:00:01
#    -------------------------------- ------- 10.7/13.3 MB 7.5 MB/s eta 0:00:01
#    --------------------------------- ------ 11.0/13.3 MB 5.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.8/13.3 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------ --- 12.3/13.3 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.3 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.3 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 13.3/13.3 MB 4.4 MB/s eta 0:00:00
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading google_auth_oauthlib-1.2.2-py3-none-any.whl (19 kB)
# Downloading google_api_core-2.24.2-py3-none-any.whl (160 kB)
# Downloading google_auth-2.39.0-py2.py3-none-any.whl (212 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Downloading protobuf-6.30.2-cp310-abi3-win_amd64.whl (431 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: uritemplate, pyasn1, protobuf, oauthlib, httplib2, cachetools, rsa, requests-oauthlib, pyasn1-modules, proto-plus, googleapis-common-protos, google-auth, google-auth-oauthlib, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed cachetools-5.5.2 google-api-core-2.24.2 google-api-python-client-2.169.0 google-auth-2.39.0 google-auth-httplib2-0.2.0 google-auth-oauthlib-1.2.2 googleapis-common-protos-1.70.0 httplib2-0.22.0 oauthlib-3.2.2 proto-plus-1.26.1 protobuf-6.30.2 pyasn1-0.6.1 pyasn1-modules-0.4.2 requests-oauthlib-2.0.0 rsa-4.9.1 uritemplate-4.1.1
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # 2. Quick start

# %% [markdown]
# ## a. Sending specific mails

# %%
import os
import pickle
import datetime
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# Carregar as credenciais do Google
def get_credentials():
    creds = None
    # O arquivo token.pickle armazena as credenciais do usuário.
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    
    # Se as credenciais não estiverem válidas ou não existirem, peça para o usuário se autenticar
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            from google_auth_oauthlib.flow import InstalledAppFlow
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json',  # Arquivo JSON de credenciais obtido na API do Google
                ['https://www.googleapis.com/auth/calendar']
            )
            creds = flow.run_local_server(port=0)
        # Salve as credenciais para futuras execuções
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)
    return creds

# Função para criar evento no Google Calendar
def create_event(service, summary, description, start_date):
    event = {
        'summary': summary,
        'description': description,
        'start': {
            'date': start_date,  # Data do evento
            'timeZone': 'UTC',
        },
        'end': {
            'date': start_date,  # Data final será a mesma para eventos de dia inteiro
            'timeZone': 'UTC',
        },
        'attendees': [
            {'email': 'gustavo@xcap.vc'},
            # Adicione outros emails de destinatários, se necessário
        ],
    }

    try:
        event = service.events().insert(
            calendarId='primary',
            body=event
        ).execute()
        print(f"Evento criado: {event.get('htmlLink')}")
    except HttpError as error:
        print(f"Erro ao criar o evento: {error}")

def main():
    # Dados de exemplo (de sua tabela)
    events = [
        ['CRWD', 'CrowdStrike Holdings Inc', '06/05/2025', '', 'Earnings Results'],
        ['CRWD', 'CrowdStrike Holdings Inc', '07/05/2025', '17:00 EST', 'Earnings Calls']
    ]

    # Autenticando com o Google Calendar API
    creds = get_credentials()
    service = build('calendar', 'v3', credentials=creds)

    # Criando eventos para as duas primeiras linhas
    for event_data in events[:2]:
        symbol, name, date, time, event_type = event_data
        summary = f"{symbol} - {name} - {event_type}"
        description = f"Hora do evento: {time}" if time else 'Sem horário específico.'
        
        # A data será utilizada para o evento de dia inteiro
        start_date = datetime.datetime.strptime(date, '%d/%m/%Y').date().isoformat()

        create_event(service, summary, description, start_date)

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 78
#      75         create_event(service, summary, description, start_date)
#      77 if __name__ == '__main__':
# ---> 78     main()
#
# Cell In[5], line 73, in main()
#      70 description = f"Event time: {time}" if time else 'No time specified.'
#      72 # A data será utilizada para o evento de dia inteiro
# ---> 73 start_date = datetime.datetime.strptime(date, '%d/%m/%Y').date().isoformat()
#      75 create_event(service, summary, description, start_date)
#
# TypeError: strptime() argument 1 must be str, not Timestamp

# %% [markdown]
# ## b. Sending spreadsheet mails

# %%
import pandas as pd
import datetime

earnings_sheet = pd.read_excel('Earnings data.xlsx')
just_new_events = earnings_sheet[earnings_sheet['Date']>datetime.datetime.today()]
just_new_events_sorted = just_new_events[::-1]

print(just_new_events_sorted)
# Out:
#    Symbol                      Name       Date       Time              Type
# 24   HIMS    Hims & Hers Health Inc 2025-05-05  17:00 EST    Earnings Calls
# 23   HIMS    Hims & Hers Health Inc 2025-05-05        NaN  Earnings Results
# 22   DDOG               Datadog Inc 2025-05-06  08:00 EST    Earnings Calls
# 21   DDOG               Datadog Inc 2025-05-06        NaN  Earnings Results
# 20    SYM              Symbotic Inc 2025-05-07  17:00 EST    Earnings Calls
# 19    SYM              Symbotic Inc 2025-05-07        NaN  Earnings Results
# 18   DASH              DoorDash Inc 2025-05-07  17:00 EST    Earnings Calls
# 17   DASH              DoorDash Inc 2025-05-07        NaN  Earnings Results
# 16   AFRM       Affirm Holdings Inc 2025-05-08  17:00 EST    Earnings Calls
# 15   AFRM       Affirm Holdings Inc 2025-05-08        NaN  Earnings Results
# 14   DKNG            DraftKings Inc 2025-05-08        NaN  Earnings Results
# 13   BILL         BILL Holdings Inc 2025-05-08  16:30 EST    Earnings Calls
# 12   BILL         BILL Holdings Inc 2025-05-08        NaN  Earnings Results
# 11   CRSP    CRISPR Therapeutics AG 2025-05-08        NaN  Earnings Results
# 10   DKNG            DraftKings Inc 2025-05-09  08:30 EST    Earnings Calls
# 9    MNDY            Monday.Com Ltd 2025-05-12  08:30 EST    Earnings Calls
# 8    MNDY            Monday.Com Ltd 2025-05-12        NaN  Earnings Results
# 7    PANW    Palo Alto Networks Inc 2025-05-20  16:30 EST    Earnings Calls
# 6    PANW    Palo Alto Networks Inc 2025-05-20        NaN  Earnings Results
# 5    SNOW             Snowflake Inc 2025-05-22  15:00 EST    Earnings Calls
# 4    SNOW             Snowflake Inc 2025-05-22        NaN  Earnings Results
# 3     MDB               MongoDB Inc 2025-05-30  17:00 EST    Earnings Calls
# 2     MDB               MongoDB Inc 2025-05-30        NaN  Earnings Results
# 1    CRWD  CrowdStrike Holdings Inc 2025-06-04  17:00 EST    Earnings Calls
# 0    CRWD  CrowdStrike Holdings Inc 2025-06-04        NaN  Earnings Results

# %%
earnings_sheet_events = just_new_events_sorted.values.tolist()
# print(earnings_sheet_events)
# print(type(earnings_sheet_events[3][3]))

# Pegando os dois primeiros valores da lista
events = earnings_sheet_events[:4]

# Imprimindo a variável
print(events)
# Out:
# [['HIMS', 'Hims & Hers Health Inc', Timestamp('2025-05-05 00:00:00'), '17:00 EST', 'Earnings Calls'], ['HIMS', 'Hims & Hers Health Inc', Timestamp('2025-05-05 00:00:00'), nan, 'Earnings Results'], ['DDOG', 'Datadog Inc', Timestamp('2025-05-06 00:00:00'), '08:00 EST', 'Earnings Calls'], ['DDOG', 'Datadog Inc', Timestamp('2025-05-06 00:00:00'), nan, 'Earnings Results']]

# %%
import os
import pickle
import datetime
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# Carregar as credenciais do Google
def get_credentials():
    creds = None
    # O arquivo token.pickle armazena as credenciais do usuário.
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    
    # Se as credenciais não estiverem válidas ou não existirem, peça para o usuário se autenticar
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            from google_auth_oauthlib.flow import InstalledAppFlow
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json',  # Arquivo JSON de credenciais obtido na API do Google
                ['https://www.googleapis.com/auth/calendar']
            )
            creds = flow.run_local_server(port=0)
        # Salve as credenciais para futuras execuções
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)
    return creds

# Função para criar evento no Google Calendar
def create_event(service, summary, description, start_date):
    event = {
        'summary': summary,
        'description': description,
        'start': {
            'date': start_date,  # Data do evento
            'timeZone': 'UTC',
        },
        'end': {
            'date': start_date,  # Data final será a mesma para eventos de dia inteiro
            'timeZone': 'UTC',
        },
        'attendees': [
            {'email': 'gustavo@xcap.vc'},
            {'email': 'rafa.tamasi@usp.br'},
            {'email': 'christian@xcap.vc'},
            {'email': 'arezende@xcap.vc'},
            {'email': 'bernardo@xcap.vc'},
            {'email': 'jonathan@xcap.vc'},
            {'email': 'jose@xcap.vc'},
            {'email': 'leonardo@xcap.vc'},
            {'email': 'mark.dinner@icwinvest.co'},
            {'email': 'rafa.tamasi@usp.br'}
            # Adicione outros emails de destinatários, se necessário
        ],
    }

    try:
        event = service.events().insert(
            calendarId='primary',
            body=event
        ).execute()
        print(f"Event created: {event.get('htmlLink')}")
    except HttpError as error:
        print(f"Error creating the event: {error}")

def main():
    limit = len(events)
    # Autenticando com o Google Calendar API
    if events[0][0] == events[1][0]:
        skip = True
    else: skip = False

    creds = get_credentials()
    service = build('calendar', 'v3', credentials=creds)
    # Criando eventos para as duas primeiras linhas
    for (index, event_data) in enumerate(events):
        if skip == False:
            symbol, name, date, time, event_type = event_data
            summary = f"{symbol} - {event_type}"
            description = f"Event time: {time}" if type(time)==str else 'No time specified.'

            # Converter datetime para string (usando strftime)
            timestamp_str = date.strftime('%d/%m/%Y')

            # Exibindo o resultado
            print(f"{symbol} - {event_type}: {timestamp_str}")
            
            # A data será utilizada para o evento de dia inteiro
            start_date = datetime.datetime.strptime(timestamp_str, '%d/%m/%Y').date().isoformat()
            print(start_date)

            create_event(service, summary, description, start_date)
        if index != limit-1:
            if (index % 2) != 0: 
                if events[index+1][0] == events[index+2][0]:
                    skip = True
            else: 
                    skip = False

if __name__ == '__main__':
    main()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=105812514131-jkusl3lq7kg1i8l4s78lrue91anbajcq.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A60645%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcalendar&state=A5wGnFavCn9GM3TOlM1HgFe1bj05rw&access_type=offline
# HIMS - Earnings Results: 05/05/2025
# 2025-05-05
# Event created: https://www.google.com/calendar/event?eid=OGVpNGVucmIwMWtvaWd2bWp0ZTFjdGo0Mm8gcmFmYWVsQHhjYXAudmM
# DDOG - Earnings Results: 06/05/2025
# 2025-05-06
# Event created: https://www.google.com/calendar/event?eid=NWZtMHVza25sbDB0ajF2MzNycnI0dTgxaDAgcmFmYWVsQHhjYXAudmM

# %% [markdown]
# # c. Correction script

# %%
from pandas import Timestamp

# Assuma que esses são seus dois arrays
old_events = events  # array antigo
from pandas import Timestamp

new_events = [
    # HIMS → mantido
    ['HIMS', 'Hims & Hers Health Inc', Timestamp('2025-05-05 00:00:00'), '17:00 EST', 'Earnings Calls'],
    ['HIMS', 'Hims & Hers Health Inc', Timestamp('2025-05-05 00:00:00'), None, 'Earnings Results'],
    
    # DDOG → modificado (+2 dias)
    ['DDOG', 'Datadog Inc', Timestamp('2025-05-08 00:00:00'), '08:00 EST', 'Earnings Calls'],
    ['DDOG', 'Datadog Inc', Timestamp('2025-05-08 00:00:00'), None, 'Earnings Results'],
    
    # SYM → removido (não incluído neste novo array)
]


# Criar conjuntos de identificação baseados na tupla (sigla, timestamp)
old_keys = {(e[0], e[2]) for e in old_events if isinstance(e[2], Timestamp)}
new_keys = {(e[0], e[2]) for e in new_events if isinstance(e[2], Timestamp)}

# print(old_events)
# print(old_keys)
# print(new_keys)

# Encontrar os eventos
same_keys = old_keys & new_keys
removed_keys = old_keys - new_keys
added_keys = new_keys - old_keys

print(same_keys)
print(removed_keys)
print(added_keys)

# Listar os eventos correspondentes
removed_events = [e for e in old_events if (e[0], e[2]) in removed_keys]
added_events = [e for e in new_events if (e[0], e[2]) in added_keys]

print(removed_events)
print(added_events)
# Out:
# {('HIMS', Timestamp('2025-05-05 00:00:00'))}
# {('DDOG', Timestamp('2025-05-06 00:00:00')), ('SYM', Timestamp('2025-05-07 00:00:00'))}
# {('DDOG', Timestamp('2025-05-08 00:00:00'))}
# [['DDOG', 'Datadog Inc', Timestamp('2025-05-06 00:00:00'), '08:00 EST', 'Earnings Calls'], ['DDOG', 'Datadog Inc', Timestamp('2025-05-06 00:00:00'), nan, 'Earnings Results'], ['SYM', 'Symbotic Inc', Timestamp('2025-05-07 00:00:00'), '17:00 EST', 'Earnings Calls'], ['SYM', 'Symbotic Inc', Timestamp('2025-05-07 00:00:00'), nan, 'Earnings Results']]
# [['DDOG', 'Datadog Inc', Timestamp('2025-05-08 00:00:00'), '08:00 EST', 'Earnings Calls'], ['DDOG', 'Datadog Inc', Timestamp('2025-05-08 00:00:00'), None, 'Earnings Results']]

# %%
from datetime import datetime

def find_closest_event(symbol, old_date, candidate_events):
    candidates = [e for e in candidate_events if e[0] == symbol and isinstance(e[2], Timestamp)]
    if not candidates:
        return None
    closest = min(candidates, key=lambda e: abs((e[2] - old_date).days))
    return closest

events_to_update = []

for old_event in removed_events:
    symbol, _, old_date, *_ = old_event
    closest_new = find_closest_event(symbol, old_date, new_events)
    if closest_new:
        events_to_update.append((old_event, closest_new))  # (original, novo mais próximo)
